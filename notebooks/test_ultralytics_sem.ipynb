# %%
from ultralytics import YOLO
from ultralytics.utils.plotting import colors  

# Custom palette (BGR format for OpenCV/Ultralytics)
custom_palette_bgr = [
    (0, 0, 0),       # Class 0: background -> Black
    (0, 255, 0),     # Class 1: cuttable -> Green (BGR: B=0, G=255, R=0)
    (255, 0, 0),     # Class 2: foliage -> Blue (BGR: B=255, G=0, R=0)
    (0, 0, 255),     # Class 3: non-traversable -> Red (BGR: B=0, G=0, R=255)
    (0, 255, 255),   # Class 4: traversable -> Yellow (BGR: B=0, G=255, R=255)
]


# Monkey-patch palette
colors.palette = custom_palette_bgr
colors.n = len(custom_palette_bgr)

# Load model
model = YOLO("yolo26n-sem.yaml").load("yolo26n-sem.pt")

# Train
results = model.train(
    data="../data/japan-pear-orchard-semantic-bg0/dataset.yaml",
    epochs=100,
    imgsz=512,
    name="pear_orchard_sem"
)
# Out:
# Transferred 364/364 items from pretrained weights
# Ultralytics 8.4.87 🚀 Python-3.12.3 torch-2.11.0+cu128 CUDA:0 (NVIDIA GeForce RTX 3090 Ti, 24240MiB)
# engine/trainer: agnostic_nms=False, amp=True, angle=1.0, augment=False, auto_augment=randaugment, batch=16, bgr=0.0, box=7.5, cache=False, cfg=None, classes=None, close_mosaic=10, cls=0.5, cls_pw=0.0, compile=False, conf=None, copy_paste=0.0, copy_paste_mode=flip, cos_lr=False, cutmix=0.0, data=../data/japan-pear-orchard-semantic-bg0/dataset.yaml, degrees=0.0, deterministic=True, device=, dfl=1.5, dis=6.0, distill_model=None, dnn=False, dropout=0.0, dynamic=False, embed=None, end2end=None, epochs=100, erasing=0.4, exist_ok=False, fliplr=0.5, flipud=0.0, format=torchscript, fraction=1.0, freeze=None, hsv_h=0.015, hsv_s=0.7, hsv_v=0.4, imgsz=512, iou=0.7, keras=False, kobj=1.0, line_width=None, lr0=0.01, lrf=0.01, mask_ratio=4, max_det=300, mixup=0.0, mode=train, model=yolo26n-sem.yaml, momentum=0.937, mosaic=1.0, multi_scale=0.0, name=pear_orchard_sem, nbs=64, nms=False, opset=None, optimize=False, optimizer=auto, overlap_mask=True, patience=100, perspective=0.0, plots=True, pose=12.0, pretrained=yolo26n-sem.pt, profile=False, project=None, quantize=None, rect=False, resume=False, retina_masks=False, rle=1.0, save=True, save_conf=False, save_crop=False, save_dir=/workspaces/mowbot-semantic-seg/notebooks/runs/semantic/pear_orchard_sem, save_frames=False, save_json=False, save_period=-1, save_txt=False, scale=0.5, seed=0, shear=0.0, show=False, show_boxes=True, show_conf=True, show_labels=True, simplify=True, single_cls=False, source=None, split=val, stream_buffer=False, task=semantic, time=None, tracker=tracktrack.yaml, translate=0.1, val=True, verbose=True, vid_stride=1, visualize=False, warmup_bias_lr=0.1, warmup_epochs=3.0, warmup_momentum=0.8, weight_decay=0.0005, workers=8, workspace=None
# Overriding model.yaml nc=19 with nc=5
#
#                    from  n    params  module                                       arguments
#   0                  -1  1       464  ultralytics.nn.modules.conv.Conv             [3, 16, 3, 2]
#   1                  -1  1      4672  ultralytics.nn.modules.conv.Conv             [16, 32, 3, 2]
#   2                  -1  1      6640  ultralytics.nn.modules.block.C3k2            [32, 64, 1, False, 0.25]
#   3                  -1  1     36992  ultralytics.nn.modules.conv.Conv             [64, 64, 3, 2]
#   4                  -1  1     26080  ultralytics.nn.modules.block.C3k2            [64, 128, 1, False, 0.25]
#   5                  -1  1    147712  ultralytics.nn.modules.conv.Conv             [128, 128, 3, 2]
#   6                  -1  1     87040  ultralytics.nn.modules.block.C3k2            [128, 128, 1, True]
#   7                  -1  1    295424  ultralytics.nn.modules.conv.Conv             [128, 256, 3, 2]
#   8                  -1  1    346112  ultralytics.nn.modules.block.C3k2            [256, 256, 1, True]
#   9                  -1  1    164608  ultralytics.nn.modules.block.SPPF            [256, 256, 5, 3, True]
#  10                  -1  1    249728  ultralytics.nn.modules.block.C2PSA           [256, 256, 1]
#  11                  -1  1         0  torch.nn.modules.upsampling.Upsample         [None, 2, 'nearest']
#  12             [-1, 6]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  13                  -1  1    119808  ultralytics.nn.modules.block.C3k2            [384, 128, 1, True]
#  14                  -1  1         0  torch.nn.modules.upsampling.Upsample         [None, 2, 'nearest']
#  15             [-1, 4]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  16                  -1  1     34304  ultralytics.nn.modules.block.C3k2            [256, 64, 1, True]
#  17            [16, 13]  1    111498  ultralytics.nn.modules.head.SemanticSegment  [5, [64, 128]]
# YOLO26n-sem summary: 133 layers, 1,631,082 parameters, 1,631,082 gradients, 4.4 GFLOPs
#
# Transferred 360/364 items from pretrained weights
# AMP: running Automatic Mixed Precision (AMP) checks...
# AMP: checks passed ✅
# train: Fast image access ✅ (ping: 0.0±0.0 ms, read: 5324.5±334.7 MB/s, size: 2063.3 KB)
# train: Scanning /workspaces/mowbot-semantic-seg/data/japan-pear-orchard-semantic-bg0/masks/train.cache... 20 masks, 0 missing, 0 corrupt: 100% ━━━━━━━━━━━━ 20/20 7.0Mit/s 0.0s
# albumentations: Blur(p=0.01, blur_limit=(3, 7)), MedianBlur(p=0.01, blur_limit=(3, 7)), ToGray(p=0.01, method='weighted_average', num_output_channels=3), CLAHE(p=0.01, clip_limit=(1.0, 4.0), tile_grid_size=(8, 8))
# val: Fast image access ✅ (ping: 0.0±0.0 ms, read: 2655.1±1010.6 MB/s, size: 2115.1 KB)
# val: Scanning /workspaces/mowbot-semantic-seg/data/japan-pear-orchard-semantic-bg0/masks/val.cache... 3 masks, 0 missing, 0 corrupt: 100% ━━━━━━━━━━━━ 3/3 572.0Kit/s 0.0s
# optimizer: 'optimizer=auto' found, ignoring 'lr0=0.01' and 'momentum=0.937' and determining best 'optimizer', 'lr0' and 'momentum' automatically...
# optimizer: AdamW(lr=0.001111, momentum=0.9) with parameter groups 60 weight(decay=0.0), 62 weight(decay=0.0005), 62 bias(decay=0.0)
# Plotting labels to /workspaces/mowbot-semantic-seg/notebooks/runs/semantic/pear_orchard_sem/labels.jpg...
# Image sizes 512 train, 512 val
# Using 8 dataloader workers
# Logging results to /workspaces/mowbot-semantic-seg/notebooks/runs/semantic/pear_orchard_sem
# Starting training for 100 epochs...
#
#       Epoch    GPU_mem    ce_loss  dice_loss   aux_loss  Instances       Size
#       1/100      1.97G      1.788     0.8187     0.5668          4        512: 100% ━━━━━━━━━━━━ 2/2 1.7s/it 3.4s4.3s
#                  Class     Images     Pixels       mIoU     PixAcc: 100% ━━━━━━━━━━━━ 1/1 3.4it/s 0.3s
#                    all          3     491520     0.0298     0.0356
#
#       Epoch    GPU_mem    ce_loss  dice_loss   aux_loss  Instances       Size
#       2/100      2.05G      1.783     0.8163     0.5669          4        512: 100% ━━━━━━━━━━━━ 2/2 3.4it/s 0.6s0.5s
#                  Class     Images     Pixels       mIoU     PixAcc: 100% ━━━━━━━━━━━━ 1/1 23.0it/s 0.0s
#                    all          3     491520      0.035      0.042
#
#       Epoch    GPU_mem    ce_loss  dice_loss   aux_loss  Instances       Size
#       3/100      2.05G       1.78     0.8239     0.5557          4        512: 100% ━━━━━━━━━━━━ 2/2 3.6it/s 0.5s0.4s
#                  Class     Images     Pixels       mIoU     PixAcc: 100% ━━━━━━━━━━━━ 1/1 22.6it/s 0.0s
#                    all          3     491520     0.0412     0.0512
#
#       Epoch    GPU_mem    ce_loss  dice_loss   aux_loss  Instances       Size
#       4/100      2.05G      1.759     0.8234     0.5443          4        512: 100% ━━━━━━━━━━━━ 2/2 3.5it/s 0.6s0.4s
#                  Class     Images     Pixels       mIoU     PixAcc: 100% ━━━━━━━━━━━━ 1/1 22.0it/s 0.0s
#                    all          3     491520     0.0596     0.0769
#
#       Epoch    GPU_mem    ce_loss  dice_loss   aux_loss  Instances       Size
#       5/100      2.05G      1.646     0.8068     0.5293          4        512: 100% ━━━━━━━━━━━━ 2/2 3.6it/s 0.6s0.4s
#                  Class     Images     Pixels       mIoU     PixAcc: 100% ━━━━━━━━━━━━ 1/1 23.9it/s 0.0s
#                    all          3     491520     0.0864      0.119
#
#       Epoch    GPU_mem    ce_loss  dice_loss   aux_loss  Instances       Size
#       6/100      2.05G       1.54     0.7947     0.5023          4        512: 100% ━━━━━━━━━━━━ 2/2 3.7it/s 0.5s0.4s
#                  Class     Images     Pixels       mIoU     PixAcc: 100% ━━━━━━━━━━━━ 1/1 22.9it/s 0.0s
#                    all          3     491520      0.124       0.19
#
#       Epoch    GPU_mem    ce_loss  dice_loss   aux_loss  Instances       Size
#       7/100      2.05G      1.408     0.7779     0.4801          4        512: 100% ━━━━━━━━━━━━ 2/2 3.4it/s 0.6s0.4s
#                  Class     Images     Pixels       mIoU     PixAcc: 100% ━━━━━━━━━━━━ 1/1 22.5it/s 0.0s
#                    all          3     491520       0.18      0.313
#
#       Epoch    GPU_mem    ce_loss  dice_loss   aux_loss  Instances       Size
#       8/100      2.05G      1.316     0.7594     0.4717          4        512: 100% ━━━━━━━━━━━━ 2/2 3.8it/s 0.5s0.3s
#                  Class     Images     Pixels       mIoU     PixAcc: 100% ━━━━━━━━━━━━ 1/1 22.0it/s 0.0s
#                    all          3     491520      0.235      0.446
#
#       Epoch    GPU_mem    ce_loss  dice_loss   aux_loss  Instances       Size
#       9/100      2.05G      1.173     0.7318     0.4489          4        512: 100% ━━━━━━━━━━━━ 2/2 3.8it/s 0.5s0.4s
#                  Class     Images     Pixels       mIoU     PixAcc: 100% ━━━━━━━━━━━━ 1/1 24.1it/s 0.0s
#                    all          3     491520      0.272      0.537
#
#       Epoch    GPU_mem    ce_loss  dice_loss   aux_loss  Instances       Size
#      10/100      2.05G        1.2       0.75     0.4332          4        512: 100% ━━━━━━━━━━━━ 2/2 3.6it/s 0.6s0.4s
#                  Class     Images     Pixels       mIoU     PixAcc: 100% ━━━━━━━━━━━━ 1/1 23.2it/s 0.0s
#                    all          3     491520      0.303      0.612
#
#       Epoch    GPU_mem    ce_loss  dice_loss   aux_loss  Instances       Size
#      11/100      2.05G      1.092     0.7343     0.4133          4        512: 100% ━━━━━━━━━━━━ 2/2 3.7it/s 0.5s0.4s
#                  Class     Images     Pixels       mIoU     PixAcc: 100% ━━━━━━━━━━━━ 1/1 22.5it/s 0.0s
#                    all          3     491520      0.334      0.678
#
#       Epoch    GPU_mem    ce_loss  dice_loss   aux_loss  Instances       Size
#      12/100      2.05G     0.9998     0.7177     0.3823          4        512: 100% ━━━━━━━━━━━━ 2/2 3.8it/s 0.5s0.4s
#                  Class     Images     Pixels       mIoU     PixAcc: 100% ━━━━━━━━━━━━ 1/1 22.7it/s 0.0s
#                    all          3     491520      0.378      0.759
#
#       Epoch    GPU_mem    ce_loss  dice_loss   aux_loss  Instances       Size
#      13/100      2.05G     0.9613     0.7148     0.3734          4        512: 100% ━━━━━━━━━━━━ 2/2 3.7it/s 0.5s0.4s
#                  Class     Images     Pixels       mIoU     PixAcc: 100% ━━━━━━━━━━━━ 1/1 21.2it/s 0.0s
#                    all          3     491520      0.416      0.806
#
#       Epoch    GPU_mem    ce_loss  dice_loss   aux_loss  Instances       Size
#      14/100      2.05G      0.905     0.6761     0.3525          4        512: 100% ━━━━━━━━━━━━ 2/2 3.8it/s 0.5s0.4s
#                  Class     Images     Pixels       mIoU     PixAcc: 100% ━━━━━━━━━━━━ 1/1 22.3it/s 0.0s
#                    all          3     491520       0.45      0.832
#
#       Epoch    GPU_mem    ce_loss  dice_loss   aux_loss  Instances       Size
#      15/100      2.05G     0.8422      0.696      0.327          4        512: 100% ━━━━━━━━━━━━ 2/2 3.7it/s 0.5s0.4s
#                  Class     Images     Pixels       mIoU     PixAcc: 100% ━━━━━━━━━━━━ 1/1 22.4it/s 0.0s
#                    all          3     491520      0.479       0.85
#
#       Epoch    GPU_mem    ce_loss  dice_loss   aux_loss  Instances       Size
#      16/100      2.05G     0.8335     0.6804     0.3174          4        512: 100% ━━━━━━━━━━━━ 2/2 3.8it/s 0.5s0.4s
#                  Class     Images     Pixels       mIoU     PixAcc: 100% ━━━━━━━━━━━━ 1/1 22.1it/s 0.0s
#                    all          3     491520      0.497      0.861
#
#       Epoch    GPU_mem    ce_loss  dice_loss   aux_loss  Instances       Size
#      17/100      2.05G     0.7965     0.6571     0.3174          4        512: 100% ━━━━━━━━━━━━ 2/2 3.7it/s 0.5s0.4s
#                  Class     Images     Pixels       mIoU     PixAcc: 100% ━━━━━━━━━━━━ 1/1 22.1it/s 0.0s
#                    all          3     491520      0.513       0.87
#
#       Epoch    GPU_mem    ce_loss  dice_loss   aux_loss  Instances       Size
#      18/100      2.05G     0.7375     0.6378     0.2929          4        512: 100% ━━━━━━━━━━━━ 2/2 3.6it/s 0.6s0.4s
#                  Class     Images     Pixels       mIoU     PixAcc: 100% ━━━━━━━━━━━━ 1/1 24.5it/s 0.0s
#                    all          3     491520      0.539      0.885
#
#       Epoch    GPU_mem    ce_loss  dice_loss   aux_loss  Instances       Size
#      19/100      2.05G     0.6557     0.6258     0.2721          4        512: 100% ━━━━━━━━━━━━ 2/2 3.7it/s 0.5s0.4s
#                  Class     Images     Pixels       mIoU     PixAcc: 100% ━━━━━━━━━━━━ 1/1 21.9it/s 0.0s
#                    all          3     491520      0.564      0.897
#
#       Epoch    GPU_mem    ce_loss  dice_loss   aux_loss  Instances       Size
#      20/100      2.05G     0.6658      0.642     0.2605          4        512: 100% ━━━━━━━━━━━━ 2/2 3.6it/s 0.6s0.4s
#                  Class     Images     Pixels       mIoU     PixAcc: 100% ━━━━━━━━━━━━ 1/1 25.2it/s 0.0s
#                    all          3     491520      0.578      0.903
#
#       Epoch    GPU_mem    ce_loss  dice_loss   aux_loss  Instances       Size
#      21/100      2.05G     0.6109     0.5817     0.2499          4        512: 100% ━━━━━━━━━━━━ 2/2 3.7it/s 0.5s0.4s
#                  Class     Images     Pixels       mIoU     PixAcc: 100% ━━━━━━━━━━━━ 1/1 22.4it/s 0.0s
#                    all          3     491520      0.588      0.906
#
#       Epoch    GPU_mem    ce_loss  dice_loss   aux_loss  Instances       Size
#      22/100      2.05G     0.5716     0.6113     0.2267          4        512: 100% ━━━━━━━━━━━━ 2/2 3.6it/s 0.6s0.4s
#                  Class     Images     Pixels       mIoU     PixAcc: 100% ━━━━━━━━━━━━ 1/1 22.6it/s 0.0s
#                    all          3     491520      0.596      0.909
#
#       Epoch    GPU_mem    ce_loss  dice_loss   aux_loss  Instances       Size
#      23/100      2.05G      0.584     0.5936      0.235          4        512: 100% ━━━━━━━━━━━━ 2/2 3.7it/s 0.5s0.4s
#                  Class     Images     Pixels       mIoU     PixAcc: 100% ━━━━━━━━━━━━ 1/1 22.3it/s 0.0s
#                    all          3     491520      0.605      0.912
#
#       Epoch    GPU_mem    ce_loss  dice_loss   aux_loss  Instances       Size
#      24/100      2.05G     0.5162     0.5777     0.2008          4        512: 100% ━━━━━━━━━━━━ 2/2 3.9it/s 0.5s0.4s
#                  Class     Images     Pixels       mIoU     PixAcc: 100% ━━━━━━━━━━━━ 1/1 23.4it/s 0.0s
#                    all          3     491520      0.612      0.914
#
#       Epoch    GPU_mem    ce_loss  dice_loss   aux_loss  Instances       Size
#      25/100      2.05G     0.4925     0.5435     0.2076          4        512: 100% ━━━━━━━━━━━━ 2/2 3.5it/s 0.6s0.4s
#                  Class     Images     Pixels       mIoU     PixAcc: 100% ━━━━━━━━━━━━ 1/1 24.2it/s 0.0s
#                    all          3     491520      0.616      0.914
#
#       Epoch    GPU_mem    ce_loss  dice_loss   aux_loss  Instances       Size
#      26/100      2.05G     0.4753      0.504      0.201          4        512: 100% ━━━━━━━━━━━━ 2/2 3.7it/s 0.5s0.3s
#                  Class     Images     Pixels       mIoU     PixAcc: 100% ━━━━━━━━━━━━ 1/1 21.3it/s 0.0s
#                    all          3     491520       0.62      0.915
#
#       Epoch    GPU_mem    ce_loss  dice_loss   aux_loss  Instances       Size
#      27/100      2.06G     0.4413     0.5077     0.1872          4        512: 100% ━━━━━━━━━━━━ 2/2 3.6it/s 0.6s0.4s
#                  Class     Images     Pixels       mIoU     PixAcc: 100% ━━━━━━━━━━━━ 1/1 22.4it/s 0.0s
#                    all          3     491520      0.623      0.917
#
#       Epoch    GPU_mem    ce_loss  dice_loss   aux_loss  Instances       Size
#      28/100      2.06G     0.4574      0.528     0.2033          4        512: 100% ━━━━━━━━━━━━ 2/2 3.6it/s 0.6s0.4s
#                  Class     Images     Pixels       mIoU     PixAcc: 100% ━━━━━━━━━━━━ 1/1 22.2it/s 0.0s
#                    all          3     491520      0.623      0.917
#
#       Epoch    GPU_mem    ce_loss  dice_loss   aux_loss  Instances       Size
#      29/100      2.06G     0.4298     0.5066     0.1813          4        512: 100% ━━━━━━━━━━━━ 2/2 3.8it/s 0.5s0.4s
#                  Class     Images     Pixels       mIoU     PixAcc: 100% ━━━━━━━━━━━━ 1/1 22.4it/s 0.0s
#                    all          3     491520      0.627      0.919
#
#       Epoch    GPU_mem    ce_loss  dice_loss   aux_loss  Instances       Size
#      30/100      2.06G     0.4005     0.4665     0.1789          4        512: 100% ━━━━━━━━━━━━ 2/2 3.8it/s 0.5s0.4s
#                  Class     Images     Pixels       mIoU     PixAcc: 100% ━━━━━━━━━━━━ 1/1 22.6it/s 0.0s
#                    all          3     491520      0.629       0.92
#
#       Epoch    GPU_mem    ce_loss  dice_loss   aux_loss  Instances       Size
#      31/100      2.06G     0.3903     0.4827     0.1706          4        512: 100% ━━━━━━━━━━━━ 2/2 3.6it/s 0.6s0.3s
#                  Class     Images     Pixels       mIoU     PixAcc: 100% ━━━━━━━━━━━━ 1/1 25.0it/s 0.0s
#                    all          3     491520      0.629       0.92
#
#       Epoch    GPU_mem    ce_loss  dice_loss   aux_loss  Instances       Size
#      32/100      2.06G     0.3988     0.4824     0.1782          4        512: 100% ━━━━━━━━━━━━ 2/2 3.7it/s 0.5s0.4s
#                  Class     Images     Pixels       mIoU     PixAcc: 100% ━━━━━━━━━━━━ 1/1 22.6it/s 0.0s
#                    all          3     491520      0.631      0.921
#
#       Epoch    GPU_mem    ce_loss  dice_loss   aux_loss  Instances       Size
#      33/100      2.06G     0.3528     0.4618     0.1578          4        512: 100% ━━━━━━━━━━━━ 2/2 3.6it/s 0.6s0.4s
#                  Class     Images     Pixels       mIoU     PixAcc: 100% ━━━━━━━━━━━━ 1/1 22.1it/s 0.0s
#                    all          3     491520      0.632      0.921
#
#       Epoch    GPU_mem    ce_loss  dice_loss   aux_loss  Instances       Size
#      34/100      2.06G     0.3733     0.4473     0.1729          4        512: 100% ━━━━━━━━━━━━ 2/2 3.6it/s 0.6s0.4s
#                  Class     Images     Pixels       mIoU     PixAcc: 100% ━━━━━━━━━━━━ 1/1 22.0it/s 0.0s
#                    all          3     491520      0.632      0.921
#
#       Epoch    GPU_mem    ce_loss  dice_loss   aux_loss  Instances       Size
#      35/100      2.06G     0.3374     0.4243     0.1555          4        512: 100% ━━━━━━━━━━━━ 2/2 3.7it/s 0.5s0.4s
#                  Class     Images     Pixels       mIoU     PixAcc: 100% ━━━━━━━━━━━━ 1/1 23.0it/s 0.0s
#                    all          3     491520      0.633      0.922
#
#       Epoch    GPU_mem    ce_loss  dice_loss   aux_loss  Instances       Size
#      36/100      2.06G     0.3489     0.4519      0.154          4        512: 100% ━━━━━━━━━━━━ 2/2 3.8it/s 0.5s0.4s
#                  Class     Images     Pixels       mIoU     PixAcc: 100% ━━━━━━━━━━━━ 1/1 22.3it/s 0.0s
#                    all          3     491520      0.637      0.923
#
#       Epoch    GPU_mem    ce_loss  dice_loss   aux_loss  Instances       Size
#      37/100      2.06G     0.3259     0.4215     0.1506          4        512: 100% ━━━━━━━━━━━━ 2/2 3.7it/s 0.5s0.4s
#                  Class     Images     Pixels       mIoU     PixAcc: 100% ━━━━━━━━━━━━ 1/1 20.8it/s 0.0s
#                    all          3     491520      0.637      0.923
#
#       Epoch    GPU_mem    ce_loss  dice_loss   aux_loss  Instances       Size
#      38/100      2.06G      0.281      0.371      0.136          4        512: 100% ━━━━━━━━━━━━ 2/2 3.7it/s 0.5s0.4s
#                  Class     Images     Pixels       mIoU     PixAcc: 100% ━━━━━━━━━━━━ 1/1 23.4it/s 0.0s
#                    all          3     491520      0.643      0.925
#
#       Epoch    GPU_mem    ce_loss  dice_loss   aux_loss  Instances       Size
#      39/100      2.06G     0.3361     0.4117     0.1518          4        512: 100% ━━━━━━━━━━━━ 2/2 3.7it/s 0.5s0.3s
#                  Class     Images     Pixels       mIoU     PixAcc: 100% ━━━━━━━━━━━━ 1/1 22.3it/s 0.0s
#                    all          3     491520      0.649      0.928
#
#       Epoch    GPU_mem    ce_loss  dice_loss   aux_loss  Instances       Size
#      40/100      2.06G     0.2754     0.3869     0.1242          4        512: 100% ━━━━━━━━━━━━ 2/2 3.7it/s 0.5s0.4s
#                  Class     Images     Pixels       mIoU     PixAcc: 100% ━━━━━━━━━━━━ 1/1 22.4it/s 0.0s
#                    all          3     491520      0.649      0.928
#
#       Epoch    GPU_mem    ce_loss  dice_loss   aux_loss  Instances       Size
#      41/100      2.06G     0.3144     0.4047     0.1445          4        512: 100% ━━━━━━━━━━━━ 2/2 3.7it/s 0.5s0.4s
#                  Class     Images     Pixels       mIoU     PixAcc: 100% ━━━━━━━━━━━━ 1/1 22.0it/s 0.0s
#                    all          3     491520      0.654      0.929
#
#       Epoch    GPU_mem    ce_loss  dice_loss   aux_loss  Instances       Size
#      42/100      2.06G      0.289     0.3977     0.1332          4        512: 100% ━━━━━━━━━━━━ 2/2 3.6it/s 0.6s0.4s
#                  Class     Images     Pixels       mIoU     PixAcc: 100% ━━━━━━━━━━━━ 1/1 22.4it/s 0.0s
#                    all          3     491520      0.659      0.931
#
#       Epoch    GPU_mem    ce_loss  dice_loss   aux_loss  Instances       Size
#      43/100      2.06G     0.2916     0.4186     0.1285          4        512: 100% ━━━━━━━━━━━━ 2/2 3.8it/s 0.5s0.4s
#                  Class     Images     Pixels       mIoU     PixAcc: 100% ━━━━━━━━━━━━ 1/1 22.2it/s 0.0s
#                    all          3     491520      0.659      0.931
#
#       Epoch    GPU_mem    ce_loss  dice_loss   aux_loss  Instances       Size
#      44/100      2.06G     0.3566     0.4004     0.1644          4        512: 100% ━━━━━━━━━━━━ 2/2 3.7it/s 0.5s0.4s
#                  Class     Images     Pixels       mIoU     PixAcc: 100% ━━━━━━━━━━━━ 1/1 24.5it/s 0.0s
#                    all          3     491520      0.665      0.932
#
#       Epoch    GPU_mem    ce_loss  dice_loss   aux_loss  Instances       Size
#      45/100      2.06G     0.2541     0.3546     0.1288          4        512: 100% ━━━━━━━━━━━━ 2/2 3.6it/s 0.6s0.4s
#                  Class     Images     Pixels       mIoU     PixAcc: 100% ━━━━━━━━━━━━ 1/1 22.5it/s 0.0s
#                    all          3     491520      0.665      0.932
#
#       Epoch    GPU_mem    ce_loss  dice_loss   aux_loss  Instances       Size
#      46/100      2.06G     0.2805     0.3825      0.136          4        512: 100% ━━━━━━━━━━━━ 2/2 3.7it/s 0.5s0.4s
#                  Class     Images     Pixels       mIoU     PixAcc: 100% ━━━━━━━━━━━━ 1/1 20.8it/s 0.0s
#                    all          3     491520      0.669      0.934
#
#       Epoch    GPU_mem    ce_loss  dice_loss   aux_loss  Instances       Size
#      47/100      2.06G     0.2775     0.3888      0.127          4        512: 100% ━━━━━━━━━━━━ 2/2 3.9it/s 0.5s0.4s
#                  Class     Images     Pixels       mIoU     PixAcc: 100% ━━━━━━━━━━━━ 1/1 22.8it/s 0.0s
#                    all          3     491520      0.669      0.934
#
#       Epoch    GPU_mem    ce_loss  dice_loss   aux_loss  Instances       Size
#      48/100      2.06G      0.268     0.3811     0.1253          4        512: 100% ━━━━━━━━━━━━ 2/2 3.6it/s 0.6s0.4s
#                  Class     Images     Pixels       mIoU     PixAcc: 100% ━━━━━━━━━━━━ 1/1 24.5it/s 0.0s
#                    all          3     491520      0.673      0.935
#
#       Epoch    GPU_mem    ce_loss  dice_loss   aux_loss  Instances       Size
#      49/100      2.06G     0.2434     0.3282     0.1189          4        512: 100% ━━━━━━━━━━━━ 2/2 3.7it/s 0.5s
#                  Class     Images     Pixels       mIoU     PixAcc: 100% ━━━━━━━━━━━━ 1/1 24.3it/s 0.0s
#                    all          3     491520      0.673      0.935
#
#       Epoch    GPU_mem    ce_loss  dice_loss   aux_loss  Instances       Size
#      50/100      2.06G     0.2596     0.3769      0.123          4        512: 100% ━━━━━━━━━━━━ 2/2 3.6it/s 0.6s0.4s
#                  Class     Images     Pixels       mIoU     PixAcc: 100% ━━━━━━━━━━━━ 1/1 22.7it/s 0.0s
#                    all          3     491520      0.673      0.935
#
#       Epoch    GPU_mem    ce_loss  dice_loss   aux_loss  Instances       Size
#      51/100      2.06G      0.241     0.3492     0.1139          4        512: 100% ━━━━━━━━━━━━ 2/2 4.0it/s 0.5s0.4s
#                  Class     Images     Pixels       mIoU     PixAcc: 100% ━━━━━━━━━━━━ 1/1 22.0it/s 0.0s
#                    all          3     491520      0.673      0.935
#
#       Epoch    GPU_mem    ce_loss  dice_loss   aux_loss  Instances       Size
#      52/100      2.06G     0.2656     0.3399      0.127          4        512: 100% ━━━━━━━━━━━━ 2/2 3.6it/s 0.6s0.4s
#                  Class     Images     Pixels       mIoU     PixAcc: 100% ━━━━━━━━━━━━ 1/1 22.4it/s 0.0s
#                    all          3     491520      0.672      0.935
#
#       Epoch    GPU_mem    ce_loss  dice_loss   aux_loss  Instances       Size
#      53/100      2.06G     0.2306     0.3557     0.1122          4        512: 100% ━━━━━━━━━━━━ 2/2 3.7it/s 0.5s0.4s
#                  Class     Images     Pixels       mIoU     PixAcc: 100% ━━━━━━━━━━━━ 1/1 22.7it/s 0.0s
#                    all          3     491520      0.672      0.935
#
#       Epoch    GPU_mem    ce_loss  dice_loss   aux_loss  Instances       Size
#      54/100      2.06G     0.2698     0.3579     0.1291          4        512: 100% ━━━━━━━━━━━━ 2/2 3.5it/s 0.6s0.4s
#                  Class     Images     Pixels       mIoU     PixAcc: 100% ━━━━━━━━━━━━ 1/1 22.5it/s 0.0s
#                    all          3     491520      0.672      0.934
#
#       Epoch    GPU_mem    ce_loss  dice_loss   aux_loss  Instances       Size
#      55/100      2.06G     0.2568     0.3551     0.1217          4        512: 100% ━━━━━━━━━━━━ 2/2 4.2it/s 0.5s0.4s
#                  Class     Images     Pixels       mIoU     PixAcc: 100% ━━━━━━━━━━━━ 1/1 23.1it/s 0.0s
#                    all          3     491520      0.672      0.934
#
#       Epoch    GPU_mem    ce_loss  dice_loss   aux_loss  Instances       Size
#      56/100      2.06G     0.2357     0.3193     0.1161          4        512: 100% ━━━━━━━━━━━━ 2/2 3.9it/s 0.5s0.4s
#                  Class     Images     Pixels       mIoU     PixAcc: 100% ━━━━━━━━━━━━ 1/1 23.7it/s 0.0s
#                    all          3     491520      0.674      0.933
#
#       Epoch    GPU_mem    ce_loss  dice_loss   aux_loss  Instances       Size
#      57/100      2.06G     0.2256     0.3352     0.1072          4        512: 100% ━━━━━━━━━━━━ 2/2 3.9it/s 0.5s0.4s
#                  Class     Images     Pixels       mIoU     PixAcc: 100% ━━━━━━━━━━━━ 1/1 22.2it/s 0.0s
#                    all          3     491520      0.674      0.933
#
#       Epoch    GPU_mem    ce_loss  dice_loss   aux_loss  Instances       Size
#      58/100      2.06G     0.2217     0.2998     0.1076          4        512: 100% ━━━━━━━━━━━━ 2/2 3.9it/s 0.5s0.4s
#                  Class     Images     Pixels       mIoU     PixAcc: 100% ━━━━━━━━━━━━ 1/1 22.1it/s 0.0s
#                    all          3     491520      0.679      0.933
#
#       Epoch    GPU_mem    ce_loss  dice_loss   aux_loss  Instances       Size
#      59/100      2.06G      0.242     0.3128     0.1198          4        512: 100% ━━━━━━━━━━━━ 2/2 3.8it/s 0.5s0.4s
#                  Class     Images     Pixels       mIoU     PixAcc: 100% ━━━━━━━━━━━━ 1/1 22.3it/s 0.0s
#                    all          3     491520      0.679      0.933
#
#       Epoch    GPU_mem    ce_loss  dice_loss   aux_loss  Instances       Size
#      60/100      2.06G     0.2137     0.3131     0.1054          4        512: 100% ━━━━━━━━━━━━ 2/2 3.7it/s 0.5s0.4s
#                  Class     Images     Pixels       mIoU     PixAcc: 100% ━━━━━━━━━━━━ 1/1 21.9it/s 0.0s
#                    all          3     491520      0.685      0.934
#
#       Epoch    GPU_mem    ce_loss  dice_loss   aux_loss  Instances       Size
#      61/100      2.06G     0.2105     0.2973     0.1017          4        512: 100% ━━━━━━━━━━━━ 2/2 3.7it/s 0.5s0.4s
#                  Class     Images     Pixels       mIoU     PixAcc: 100% ━━━━━━━━━━━━ 1/1 22.1it/s 0.0s
#                    all          3     491520      0.685      0.934
#
#       Epoch    GPU_mem    ce_loss  dice_loss   aux_loss  Instances       Size
#      62/100      2.06G     0.2253     0.3072     0.1136          4        512: 100% ━━━━━━━━━━━━ 2/2 3.7it/s 0.5s0.4s
#                  Class     Images     Pixels       mIoU     PixAcc: 100% ━━━━━━━━━━━━ 1/1 24.1it/s 0.0s
#                    all          3     491520      0.691      0.936
#
#       Epoch    GPU_mem    ce_loss  dice_loss   aux_loss  Instances       Size
#      63/100      2.06G     0.2002     0.2984     0.1021          4        512: 100% ━━━━━━━━━━━━ 2/2 3.7it/s 0.5s0.4s
#                  Class     Images     Pixels       mIoU     PixAcc: 100% ━━━━━━━━━━━━ 1/1 25.0it/s 0.0s
#                    all          3     491520      0.691      0.936
#
#       Epoch    GPU_mem    ce_loss  dice_loss   aux_loss  Instances       Size
#      64/100      2.06G     0.1986     0.2948     0.1024          4        512: 100% ━━━━━━━━━━━━ 2/2 3.5it/s 0.6s0.4s
#                  Class     Images     Pixels       mIoU     PixAcc: 100% ━━━━━━━━━━━━ 1/1 23.6it/s 0.0s
#                    all          3     491520      0.695      0.938
#
#       Epoch    GPU_mem    ce_loss  dice_loss   aux_loss  Instances       Size
#      65/100      2.06G     0.2171     0.3563    0.09902          4        512: 100% ━━━━━━━━━━━━ 2/2 3.7it/s 0.5s0.4s
#                  Class     Images     Pixels       mIoU     PixAcc: 100% ━━━━━━━━━━━━ 1/1 22.3it/s 0.0s
#                    all          3     491520      0.695      0.938
#
#       Epoch    GPU_mem    ce_loss  dice_loss   aux_loss  Instances       Size
#      66/100      2.06G     0.2113     0.3066     0.1004          4        512: 100% ━━━━━━━━━━━━ 2/2 3.6it/s 0.6s0.4s
#                  Class     Images     Pixels       mIoU     PixAcc: 100% ━━━━━━━━━━━━ 1/1 22.5it/s 0.0s
#                    all          3     491520      0.696      0.938
#
#       Epoch    GPU_mem    ce_loss  dice_loss   aux_loss  Instances       Size
#      67/100      2.06G      0.228     0.2844     0.1157          4        512: 100% ━━━━━━━━━━━━ 2/2 3.7it/s 0.5s0.4s
#                  Class     Images     Pixels       mIoU     PixAcc: 100% ━━━━━━━━━━━━ 1/1 22.0it/s 0.0s
#                    all          3     491520      0.696      0.938
#
#       Epoch    GPU_mem    ce_loss  dice_loss   aux_loss  Instances       Size
#      68/100      2.06G     0.2016      0.303     0.1002          4        512: 100% ━━━━━━━━━━━━ 2/2 3.7it/s 0.5s0.4s
#                  Class     Images     Pixels       mIoU     PixAcc: 100% ━━━━━━━━━━━━ 1/1 24.3it/s 0.0s
#                    all          3     491520      0.698      0.939
#
#       Epoch    GPU_mem    ce_loss  dice_loss   aux_loss  Instances       Size
#      69/100      2.06G      0.183     0.2946    0.09479          4        512: 100% ━━━━━━━━━━━━ 2/2 3.8it/s 0.5s0.4s
#                  Class     Images     Pixels       mIoU     PixAcc: 100% ━━━━━━━━━━━━ 1/1 21.9it/s 0.0s
#                    all          3     491520      0.698      0.939
#
#       Epoch    GPU_mem    ce_loss  dice_loss   aux_loss  Instances       Size
#      70/100      2.06G     0.1832     0.2822    0.09515          4        512: 100% ━━━━━━━━━━━━ 2/2 3.6it/s 0.5s0.4s
#                  Class     Images     Pixels       mIoU     PixAcc: 100% ━━━━━━━━━━━━ 1/1 23.1it/s 0.0s
#                    all          3     491520        0.7       0.94
#
#       Epoch    GPU_mem    ce_loss  dice_loss   aux_loss  Instances       Size
#      71/100      2.06G     0.1837     0.2655    0.09384          4        512: 100% ━━━━━━━━━━━━ 2/2 3.8it/s 0.5s0.3s
#                  Class     Images     Pixels       mIoU     PixAcc: 100% ━━━━━━━━━━━━ 1/1 22.3it/s 0.0s
#                    all          3     491520        0.7       0.94
#
#       Epoch    GPU_mem    ce_loss  dice_loss   aux_loss  Instances       Size
#      72/100      2.06G     0.2016     0.3104    0.09862          4        512: 100% ━━━━━━━━━━━━ 2/2 3.9it/s 0.5s0.4s
#                  Class     Images     Pixels       mIoU     PixAcc: 100% ━━━━━━━━━━━━ 1/1 22.3it/s 0.0s
#                    all          3     491520      0.703      0.942
#
#       Epoch    GPU_mem    ce_loss  dice_loss   aux_loss  Instances       Size
#      73/100      2.06G     0.2051      0.281    0.09956          4        512: 100% ━━━━━━━━━━━━ 2/2 3.9it/s 0.5s0.4s
#                  Class     Images     Pixels       mIoU     PixAcc: 100% ━━━━━━━━━━━━ 1/1 23.0it/s 0.0s
#                    all          3     491520      0.703      0.942
#
#       Epoch    GPU_mem    ce_loss  dice_loss   aux_loss  Instances       Size
#      74/100      2.06G     0.2227     0.3146     0.1078          4        512: 100% ━━━━━━━━━━━━ 2/2 3.6it/s 0.5s0.4s
#                  Class     Images     Pixels       mIoU     PixAcc: 100% ━━━━━━━━━━━━ 1/1 22.0it/s 0.0s
#                    all          3     491520      0.705      0.943
#
#       Epoch    GPU_mem    ce_loss  dice_loss   aux_loss  Instances       Size
#      75/100      2.06G     0.1836     0.2629    0.09928          4        512: 100% ━━━━━━━━━━━━ 2/2 3.6it/s 0.6s0.4s
#                  Class     Images     Pixels       mIoU     PixAcc: 100% ━━━━━━━━━━━━ 1/1 22.3it/s 0.0s
#                    all          3     491520      0.705      0.943
#
#       Epoch    GPU_mem    ce_loss  dice_loss   aux_loss  Instances       Size
#      76/100      2.06G     0.1737       0.26     0.0912          4        512: 100% ━━━━━━━━━━━━ 2/2 3.9it/s 0.5s0.4s
#                  Class     Images     Pixels       mIoU     PixAcc: 100% ━━━━━━━━━━━━ 1/1 22.6it/s 0.0s
#                    all          3     491520      0.705      0.942
#
#       Epoch    GPU_mem    ce_loss  dice_loss   aux_loss  Instances       Size
#      77/100      2.06G     0.2202     0.3152     0.1078          4        512: 100% ━━━━━━━━━━━━ 2/2 4.0it/s 0.5s0.4s
#                  Class     Images     Pixels       mIoU     PixAcc: 100% ━━━━━━━━━━━━ 1/1 22.6it/s 0.0s
#                    all          3     491520      0.705      0.942
#
#       Epoch    GPU_mem    ce_loss  dice_loss   aux_loss  Instances       Size
#      78/100      2.06G     0.1769     0.2691    0.09282          4        512: 100% ━━━━━━━━━━━━ 2/2 3.7it/s 0.5s0.4s
#                  Class     Images     Pixels       mIoU     PixAcc: 100% ━━━━━━━━━━━━ 1/1 22.7it/s 0.0s
#                    all          3     491520      0.704      0.941
#
#       Epoch    GPU_mem    ce_loss  dice_loss   aux_loss  Instances       Size
#      79/100      2.06G       0.22     0.2791     0.1116          4        512: 100% ━━━━━━━━━━━━ 2/2 3.9it/s 0.5s0.3s
#                  Class     Images     Pixels       mIoU     PixAcc: 100% ━━━━━━━━━━━━ 1/1 22.1it/s 0.0s
#                    all          3     491520      0.704      0.941
#
#       Epoch    GPU_mem    ce_loss  dice_loss   aux_loss  Instances       Size
#      80/100      2.06G     0.1968     0.2921    0.09889          4        512: 100% ━━━━━━━━━━━━ 2/2 3.7it/s 0.5s0.4s
#                  Class     Images     Pixels       mIoU     PixAcc: 100% ━━━━━━━━━━━━ 1/1 22.7it/s 0.0s
#                    all          3     491520      0.705      0.941
#
#       Epoch    GPU_mem    ce_loss  dice_loss   aux_loss  Instances       Size
#      81/100      2.06G      0.171     0.2813    0.08513          4        512: 100% ━━━━━━━━━━━━ 2/2 3.8it/s 0.5s0.4s
#                  Class     Images     Pixels       mIoU     PixAcc: 100% ━━━━━━━━━━━━ 1/1 23.3it/s 0.0s
#                    all          3     491520      0.705      0.941
#
#       Epoch    GPU_mem    ce_loss  dice_loss   aux_loss  Instances       Size
#      82/100      2.06G     0.2252     0.3391     0.1072          4        512: 100% ━━━━━━━━━━━━ 2/2 3.4it/s 0.6s0.4s
#                  Class     Images     Pixels       mIoU     PixAcc: 100% ━━━━━━━━━━━━ 1/1 22.2it/s 0.0s
#                    all          3     491520      0.708      0.942
#
#       Epoch    GPU_mem    ce_loss  dice_loss   aux_loss  Instances       Size
#      83/100      2.06G     0.1786     0.2556    0.09158          4        512: 100% ━━━━━━━━━━━━ 2/2 3.9it/s 0.5s0.4s
#                  Class     Images     Pixels       mIoU     PixAcc: 100% ━━━━━━━━━━━━ 1/1 22.5it/s 0.0s
#                    all          3     491520      0.708      0.942
#
#       Epoch    GPU_mem    ce_loss  dice_loss   aux_loss  Instances       Size
#      84/100      2.06G     0.1967      0.272    0.09803          4        512: 100% ━━━━━━━━━━━━ 2/2 3.8it/s 0.5s0.4s
#                  Class     Images     Pixels       mIoU     PixAcc: 100% ━━━━━━━━━━━━ 1/1 22.8it/s 0.0s
#                    all          3     491520      0.711      0.943
#
#       Epoch    GPU_mem    ce_loss  dice_loss   aux_loss  Instances       Size
#      85/100      2.06G     0.1635      0.278    0.08587          4        512: 100% ━━━━━━━━━━━━ 2/2 3.5it/s 0.6s0.4s
#                  Class     Images     Pixels       mIoU     PixAcc: 100% ━━━━━━━━━━━━ 1/1 22.5it/s 0.0s
#                    all          3     491520      0.711      0.943
#
#       Epoch    GPU_mem    ce_loss  dice_loss   aux_loss  Instances       Size
#      86/100      2.06G     0.1703     0.2541    0.08927          4        512: 100% ━━━━━━━━━━━━ 2/2 3.8it/s 0.5s0.4s
#                  Class     Images     Pixels       mIoU     PixAcc: 100% ━━━━━━━━━━━━ 1/1 24.5it/s 0.0s
#                    all          3     491520      0.712      0.943
#
#       Epoch    GPU_mem    ce_loss  dice_loss   aux_loss  Instances       Size
#      87/100      2.06G     0.1872     0.3027    0.08638          4        512: 100% ━━━━━━━━━━━━ 2/2 3.8it/s 0.5s0.4s
#                  Class     Images     Pixels       mIoU     PixAcc: 100% ━━━━━━━━━━━━ 1/1 24.2it/s 0.0s
#                    all          3     491520      0.712      0.943
#
#       Epoch    GPU_mem    ce_loss  dice_loss   aux_loss  Instances       Size
#      88/100      2.06G     0.1718     0.2886     0.0856          4        512: 100% ━━━━━━━━━━━━ 2/2 3.6it/s 0.6s0.4s
#                  Class     Images     Pixels       mIoU     PixAcc: 100% ━━━━━━━━━━━━ 1/1 23.0it/s 0.0s
#                    all          3     491520      0.713      0.943
#
#       Epoch    GPU_mem    ce_loss  dice_loss   aux_loss  Instances       Size
#      89/100      2.06G      0.172     0.2507    0.08733          4        512: 100% ━━━━━━━━━━━━ 2/2 3.8it/s 0.5s0.4s
#                  Class     Images     Pixels       mIoU     PixAcc: 100% ━━━━━━━━━━━━ 1/1 22.8it/s 0.0s
#                    all          3     491520      0.713      0.943
#
#       Epoch    GPU_mem    ce_loss  dice_loss   aux_loss  Instances       Size
#      90/100      2.06G       0.18     0.2608    0.09228          4        512: 100% ━━━━━━━━━━━━ 2/2 3.7it/s 0.5s0.4s
#                  Class     Images     Pixels       mIoU     PixAcc: 100% ━━━━━━━━━━━━ 1/1 22.5it/s 0.0s
#                    all          3     491520      0.711      0.943
# Closing dataloader mosaic
# albumentations: Blur(p=0.01, blur_limit=(3, 7)), MedianBlur(p=0.01, blur_limit=(3, 7)), ToGray(p=0.01, method='weighted_average', num_output_channels=3), CLAHE(p=0.01, clip_limit=(1.0, 4.0), tile_grid_size=(8, 8))
#
#       Epoch    GPU_mem    ce_loss  dice_loss   aux_loss  Instances       Size
#      91/100      2.06G     0.2548     0.2927     0.1148          4        512: 100% ━━━━━━━━━━━━ 2/2 2.2it/s 0.9s
#                  Class     Images     Pixels       mIoU     PixAcc: 100% ━━━━━━━━━━━━ 1/1 20.4it/s 0.0s
#                    all          3     491520      0.711      0.943
#
#       Epoch    GPU_mem    ce_loss  dice_loss   aux_loss  Instances       Size
#      92/100      2.06G     0.1741     0.2792    0.08835          4        512: 100% ━━━━━━━━━━━━ 2/2 3.9it/s 0.5s0.4s
#                  Class     Images     Pixels       mIoU     PixAcc: 100% ━━━━━━━━━━━━ 1/1 20.7it/s 0.0s
#                    all          3     491520      0.708      0.943
#
#       Epoch    GPU_mem    ce_loss  dice_loss   aux_loss  Instances       Size
#      93/100      2.06G     0.1762     0.2726     0.0863          4        512: 100% ━━━━━━━━━━━━ 2/2 4.2it/s 0.5s0.3s
#                  Class     Images     Pixels       mIoU     PixAcc: 100% ━━━━━━━━━━━━ 1/1 22.6it/s 0.0s
#                    all          3     491520      0.708      0.943
#
#       Epoch    GPU_mem    ce_loss  dice_loss   aux_loss  Instances       Size
#      94/100      2.06G     0.1989     0.2858     0.0991          4        512: 100% ━━━━━━━━━━━━ 2/2 3.8it/s 0.5s0.4s
#                  Class     Images     Pixels       mIoU     PixAcc: 100% ━━━━━━━━━━━━ 1/1 22.4it/s 0.0s
#                    all          3     491520      0.706      0.943
#
#       Epoch    GPU_mem    ce_loss  dice_loss   aux_loss  Instances       Size
#      95/100      2.06G     0.2031     0.2946     0.0925          4        512: 100% ━━━━━━━━━━━━ 2/2 4.1it/s 0.5s0.4s
#                  Class     Images     Pixels       mIoU     PixAcc: 100% ━━━━━━━━━━━━ 1/1 24.1it/s 0.0s
#                    all          3     491520      0.706      0.943
#
#       Epoch    GPU_mem    ce_loss  dice_loss   aux_loss  Instances       Size
#      96/100      2.06G     0.1623      0.246    0.08329          4        512: 100% ━━━━━━━━━━━━ 2/2 3.9it/s 0.5s0.4s
#                  Class     Images     Pixels       mIoU     PixAcc: 100% ━━━━━━━━━━━━ 1/1 22.4it/s 0.0s
#                    all          3     491520      0.705      0.942
#
#       Epoch    GPU_mem    ce_loss  dice_loss   aux_loss  Instances       Size
#      97/100      2.06G     0.1541     0.2579    0.08241          4        512: 100% ━━━━━━━━━━━━ 2/2 4.1it/s 0.5s0.4s
#                  Class     Images     Pixels       mIoU     PixAcc: 100% ━━━━━━━━━━━━ 1/1 22.2it/s 0.0s
#                    all          3     491520      0.705      0.942
#
#       Epoch    GPU_mem    ce_loss  dice_loss   aux_loss  Instances       Size
#      98/100      2.06G     0.1485     0.2224    0.08031          4        512: 100% ━━━━━━━━━━━━ 2/2 4.3it/s 0.5s0.4s
#                  Class     Images     Pixels       mIoU     PixAcc: 100% ━━━━━━━━━━━━ 1/1 22.2it/s 0.0s
#                    all          3     491520      0.704      0.942
#
#       Epoch    GPU_mem    ce_loss  dice_loss   aux_loss  Instances       Size
#      99/100      2.06G     0.1573      0.276    0.08098          4        512: 100% ━━━━━━━━━━━━ 2/2 4.0it/s 0.5s
#                  Class     Images     Pixels       mIoU     PixAcc: 100% ━━━━━━━━━━━━ 1/1 22.2it/s 0.0s
#                    all          3     491520      0.704      0.942
#
#       Epoch    GPU_mem    ce_loss  dice_loss   aux_loss  Instances       Size
#     100/100      2.06G     0.1509     0.2761    0.07976          4        512: 100% ━━━━━━━━━━━━ 2/2 3.8it/s 0.5s0.4s
#                  Class     Images     Pixels       mIoU     PixAcc: 100% ━━━━━━━━━━━━ 1/1 22.6it/s 0.0s
#                    all          3     491520      0.704      0.942
#
# 100 epochs completed in 0.020 hours.
# Optimizer stripped from /workspaces/mowbot-semantic-seg/notebooks/runs/semantic/pear_orchard_sem/weights/last.pt, 3.4MB
# Optimizer stripped from /workspaces/mowbot-semantic-seg/notebooks/runs/semantic/pear_orchard_sem/weights/best.pt, 3.4MB
#
# Validating /workspaces/mowbot-semantic-seg/notebooks/runs/semantic/pear_orchard_sem/weights/best.pt...
# Ultralytics 8.4.87 🚀 Python-3.12.3 torch-2.11.0+cu128 CUDA:0 (NVIDIA GeForce RTX 3090 Ti, 24240MiB)
# YOLO26n-sem summary (fused): 73 layers, 1,626,002 parameters, 0 gradients, 4.3 GFLOPs
#                  Class     Images     Pixels       mIoU     PixAcc: 100% ━━━━━━━━━━━━ 1/1 205.1it/s 0.0s
#                    all          3     491520      0.713      0.943
#             background          3      11293      0.578      0.695
#               cuttable          3     297920       0.94      0.956
#                foliage          3     150112      0.911      0.974
#        non-traversable          3      12053      0.499      0.618
#            traversable          3      20142      0.635      0.865
# Speed: 0.2ms preprocess, 0.7ms inference, 0.0ms loss, 0.3ms postprocess per image
# Results saved to /workspaces/mowbot-semantic-seg/notebooks/runs/semantic/pear_orchard_sem
